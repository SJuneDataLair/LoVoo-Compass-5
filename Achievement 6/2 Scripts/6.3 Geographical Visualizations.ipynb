# %% [markdown]
# # Content Library
# * Importing Libraries and Data
# * Data Wrangling
# * Data Cleaning
# * Creating Chloropleth Map

# %% [markdown]
# # 1 Import Libraries and Data

# %%
#libraries
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib
import folium
import json

# %%
#dataset
df=pd.read_csv(r'C:\Users\Samth\CareerFoundry Projects\Achievement 6\1 Data\Manipulated Data\userapi_clean.csv')

# %%
#import json file for geographical component
geomap=r'C:\Users\Samth\CareerFoundry Projects\Achievement 6\1 Data\Manipulated Data\custom.geo.json'

# %%
#prompt for visuals to view in notebook
# %matplotlib inline

# %% [markdown]
# # 2 Data Wrangling

# %%
#viewing dataset columns
df.columns
# Out:
# Index(['Unnamed: 0', 'gender', 'genderLooking', 'age', 'counts_details',
#        'counts_pictures', 'counts_profileVisits', 'counts_kisses',
#        'counts_fans', 'counts_g', 'flirtInterests_chat',
#        'flirtInterests_friends', 'flirtInterests_date', 'country', 'city',
#        'location', 'distance', 'isFlirtstar', 'isHighlighted', 'isInfluencer',
#        'isMobile', 'isNew', 'isOnline', 'isVip', 'lang_count', 'lang_fr',
#        'lang_en', 'lang_de', 'lang_it', 'lang_es', 'lang_pt', 'verified',
#        'shareProfileEnabled', 'lastOnlineDate', 'lastOnlineTime', 'userId'],
#       dtype='object')

# %%
#creating subset with columns needed only for analysis/map 
df2=df.drop(columns=['Unnamed: 0','counts_details','counts_pictures','counts_g','flirtInterests_chat','flirtInterests_friends','flirtInterests_date','distance','isFlirtstar','isHighlighted','isInfluencer','isMobile','isNew','isOnline','isVip','lang_count','lang_fr','lang_en','lang_de','lang_it','lang_es','lang_pt','verified','shareProfileEnabled'])

# %%
#viewing new subset with needed columns
df2.head()
# Out:
#   gender genderLooking  age  counts_profileVisits  counts_kisses  counts_fans  \
# 0      F             M   25                  8279            239            0
# 1      F             M   22                   663             13            0
# 2      F             M   21                  1369             88            0
# 3      F          none   20                 22187           1015            2
# 4      F             M   21                 35262           1413            9
#
#   country        city location        lastOnlineDate  lastOnlineTime  \
# 0      CH  Rothenburg  Rümlang  2015-04-25T20:43:26Z    1.429995e+09
# 1      CH     Sissach  Sissach  2015-04-26T09:19:35Z    1.430040e+09
# 2      CH        Bâle     Bâle  2015-04-06T14:24:07Z    1.428330e+09
# 3      CA    Montréal    Berne  2015-04-07T11:21:01Z    1.428406e+09
# 4      DE     Rastatt  Rastatt  2015-04-06T14:25:20Z    1.428330e+09
#
#                      userId
# 0  55303fc3160ba0eb728b4575
# 1  552e7b61c66da10d1e8b4c82
# 2  54a584ecc56da128638b4674
# 3  54c92738076ea1b5338b4735
# 4  54e1a6f6c76da135748b4a3a

# %%
#creating flag for user age groups
df2.loc[df2['age'] >= 25, 'Age Category']= 'Late Twenties'

# %%
df2.loc[df2['age'] < 25, 'Age Category']= 'Early Twenties'

# %%
#viewing count and data type of new category
df2['Age Category'].value_counts(dropna=False)
# Out:
# Age Category
# Early Twenties    3146
# Late Twenties      426
# Name: count, dtype: int64

# %% [markdown]
# #### We learn new valuable information that 88% of the women in the dataset are younger woman in their early twenties, under the age of 25. By using data we already have and our newly wrangled data, the goal is to create a map that either shows how the age demographic is spread across countries, or the popularity of users across different countries. Possibly both!

# %%
#viewing subset with new flags
df2.head()
# Out:
#   gender genderLooking  age  counts_profileVisits  counts_kisses  counts_fans  \
# 0      F             M   25                  8279            239            0
# 1      F             M   22                   663             13            0
# 2      F             M   21                  1369             88            0
# 3      F          none   20                 22187           1015            2
# 4      F             M   21                 35262           1413            9
#
#   country        city location        lastOnlineDate  lastOnlineTime  \
# 0      CH  Rothenburg  Rümlang  2015-04-25T20:43:26Z    1.429995e+09
# 1      CH     Sissach  Sissach  2015-04-26T09:19:35Z    1.430040e+09
# 2      CH        Bâle     Bâle  2015-04-06T14:24:07Z    1.428330e+09
# 3      CA    Montréal    Berne  2015-04-07T11:21:01Z    1.428406e+09
# 4      DE     Rastatt  Rastatt  2015-04-06T14:25:20Z    1.428330e+09
#
#                      userId    Age Category
# 0  55303fc3160ba0eb728b4575   Late Twenties
# 1  552e7b61c66da10d1e8b4c82  Early Twenties
# 2  54a584ecc56da128638b4674  Early Twenties
# 3  54c92738076ea1b5338b4735  Early Twenties
# 4  54e1a6f6c76da135748b4a3a  Early Twenties

# %% [markdown]
# # 3 Data Cleaning

# %%
#checking for any missing values in the dataset
df2.isnull().sum()
# Out:
# gender                  0
# genderLooking           0
# age                     0
# counts_profileVisits    0
# counts_kisses           0
# counts_fans             0
# country                 0
# city                    0
# location                0
# lastOnlineDate          0
# lastOnlineTime          0
# userId                  0
# Age Category            0
# dtype: int64

# %%
#checking for duplicates
dups=df2.duplicated()

# %%
dups.shape #no duplicates found
# Out:
# (3572,)

# %%
#checking for extreme values in kisses/likes column
df2[df2['counts_kisses'] >2000]
# Out:
#     gender genderLooking  age  counts_profileVisits  counts_kisses  \
# 8        F             M   20                 29984           2389
# 12       F             M   22                 31736           2102
# 30       F             M   24                 51339           2926
# 60       F             M   19                 48980           2358
# 62       F             M   20                 33528           3679
# 76       F             M   20                 51560           6155
# 90       F             M   21                 52465           3739
# 97       F             M   24                 43796           2750
# 112      F          none   19                 29903           2146
# 113      F             M   23                 50275           3687
# 128      F          none   19                 22226           2338
# 132      F             M   22                 47475           2137
# 150      F             M   21                 44883           3556
# 152      F             M   20                 49039           4269
# 155      F             M   23                164425           9288
# 161      F             M   19                 38561           4527
# 165      F             M   19                 27780           2187
# 211      F             M   23                 34282           2135
# 227      F             M   23                 14856           4436
# 235      F             M   23                 58944           3599
# 249      F             M   22                 40214           3099
# 421      F             M   21                 40040           2674
# 489      F             M   26                 47248           2265
# 702      F             M   21                 51809           4114
#
#      counts_fans country                            city             location  \
# 8             10      CH                          Gstaad          Steffisburg
# 12             6      DE                         Neu-Ulm             Holzheim
# 30             1      CH                      Erlinsbach      Erlinsbach (AG)
# 60            28      CH                     Würenlingen          Würenlingen
# 62            32      CH                           Basel                Basel
# 76            18      CH                      Siglistorf            Steinmaur
# 90             4      CH                        Fribourg           Schwarzsee
# 97             2      CH  Emmenbrücke (Lucerna, Schweiz)                Emmen
# 112            0      CH                          Zürich               Zürich
# 113            0      DE               Bergisch Gladbach    Bergisch Gladbach
# 128            1      CH                          Zürich               Zürich
# 132            0      CH                          Zurigo               Urdorf
# 150           14      CH                          Zürich                Uster
# 152            0      CH                          Zürich                 Sins
# 155            0      DE                            Köln                 Köln
# 161            0      CH                            Cham                 Cham
# 165            0      CH                        Lenzburg             Lenzburg
# 211            0      CH                          Zürich               Zürich
# 227           11      DE             Rheinfelden (Baden)  Rheinfelden (Baden)
# 235            0      CH                           Olten             Pratteln
# 249            0      CH                           Baden           Fislisbach
# 421           24      CH                          Zürich          Niederhasli
# 489            0      IT                          Milano               Milano
# 702            0      BR                        Curitiba                 Lyon
#
#            lastOnlineDate  lastOnlineTime                    userId  \
# 8    2015-04-07T20:01:55Z    1.428437e+09  550c8310066ea13f808b4b35
# 12   2015-04-06T14:52:17Z    1.428332e+09  54fa217d190ba0a1618b4668
# 30   2015-04-08T10:38:36Z    1.428490e+09  552025c01c0ba01e1b8b4588
# 60   2015-04-26T11:04:52Z    1.430046e+09  5525ad66140ba01c5b8b496d
# 62   2015-04-08T15:19:24Z    1.428506e+09  55038f65c96da15c998b4a4c
# 76   2015-04-26T11:47:45Z    1.430049e+09  55380277c66da1264a8b47ef
# 90   2015-04-26T10:45:05Z    1.430045e+09  553a3ff7086ea1d37d8b50bc
# 97   2015-04-26T06:07:35Z    1.430028e+09  54c34090190ba0a5428b4ec5
# 112  2015-04-26T09:14:13Z    1.430040e+09  55076dc41b0ba0d9208b478a
# 113  2015-04-06T14:52:29Z    1.428332e+09  55205176160ba031038b4bbe
# 128  2015-04-08T06:16:21Z    1.428474e+09  550d6ef6e96da185088b4a8b
# 132  2015-04-26T13:03:06Z    1.430053e+09  553cc2661a0ba0f12a8b47c8
# 150  2015-04-26T18:39:49Z    1.430074e+09  544293c7170ba0ae088b4745
# 152  2015-04-08T14:40:32Z    1.428504e+09  51989e28c66da1845d000399
# 155  2015-04-19T11:42:53Z    1.429444e+09  55229ec5ea6da1d7038b46a3
# 161  2015-04-06T14:31:14Z    1.428331e+09  5319963fcb6da1066d8b4641
# 165  2015-04-05T23:36:29Z    1.428277e+09  5463baf8c46da1773a8b4ac0
# 211  2015-04-18T23:56:13Z    1.429401e+09  552e463b0b6ea135668b463f
# 227  2015-04-03T12:16:17Z    1.428063e+09  550e1823c56da1e80b8b4c1f
# 235  2015-04-26T18:56:58Z    1.430075e+09  55301239e56da16e9f8b457c
# 249  2015-04-07T16:57:16Z    1.428426e+09  551c6be21a0ba0006b8b4942
# 421  2015-04-26T11:27:49Z    1.430048e+09  55106ec90a6ea115268b4a12
# 489  2015-04-18T18:42:43Z    1.429383e+09  5478c992c56da1a3188b45d3
# 702  2015-04-08T07:24:04Z    1.428478e+09  550ffdb3c56da1de698b4c66
#
#        Age Category
# 8    Early Twenties
# 12   Early Twenties
# 30   Early Twenties
# 60   Early Twenties
# 62   Early Twenties
# 76   Early Twenties
# 90   Early Twenties
# 97   Early Twenties
# 112  Early Twenties
# 113  Early Twenties
# 128  Early Twenties
# 132  Early Twenties
# 150  Early Twenties
# 152  Early Twenties
# 155  Early Twenties
# 161  Early Twenties
# 165  Early Twenties
# 211  Early Twenties
# 227  Early Twenties
# 235  Early Twenties
# 249  Early Twenties
# 421  Early Twenties
# 489   Late Twenties
# 702  Early Twenties

# %% [markdown]
# #### Although there are some extreme values in the dataset, I will only change the values of those values higher than 5000 kisses as it is not representative of the typical user's kisses history

# %%
#creating new check for extreme values higher than 5000
df2[df2['counts_kisses']>5000]
# Out:
#     gender genderLooking  age  counts_profileVisits  counts_kisses  \
# 76       F             M   20                 51560           6155
# 155      F             M   23                164425           9288
#
#      counts_fans country        city   location        lastOnlineDate  \
# 76            18      CH  Siglistorf  Steinmaur  2015-04-26T11:47:45Z
# 155            0      DE        Köln       Köln  2015-04-19T11:42:53Z
#
#      lastOnlineTime                    userId    Age Category
# 76     1.430049e+09  55380277c66da1264a8b47ef  Early Twenties
# 155    1.429444e+09  55229ec5ea6da1d7038b46a3  Early Twenties

# %%
#attempting to replace values
df2['counts_kisses'] = np.where(df2['counts_kisses']>5000, [5000],df['counts_kisses'])

# %%
#viewing desc stats for column 
df2.head()
# Out:
#   gender genderLooking  age  counts_profileVisits  counts_kisses  counts_fans  \
# 0      F             M   25                  8279            239            0
# 1      F             M   22                   663             13            0
# 2      F             M   21                  1369             88            0
# 3      F          none   20                 22187           1015            2
# 4      F             M   21                 35262           1413            9
#
#   country        city location        lastOnlineDate  lastOnlineTime  \
# 0      CH  Rothenburg  Rümlang  2015-04-25T20:43:26Z    1.429995e+09
# 1      CH     Sissach  Sissach  2015-04-26T09:19:35Z    1.430040e+09
# 2      CH        Bâle     Bâle  2015-04-06T14:24:07Z    1.428330e+09
# 3      CA    Montréal    Berne  2015-04-07T11:21:01Z    1.428406e+09
# 4      DE     Rastatt  Rastatt  2015-04-06T14:25:20Z    1.428330e+09
#
#                      userId    Age Category
# 0  55303fc3160ba0eb728b4575   Late Twenties
# 1  552e7b61c66da10d1e8b4c82  Early Twenties
# 2  54a584ecc56da128638b4674  Early Twenties
# 3  54c92738076ea1b5338b4735  Early Twenties
# 4  54e1a6f6c76da135748b4a3a  Early Twenties

# %%
#verifying extreme values were replaced
df2[df2['counts_kisses']>5000] #all extreme values have been replaced
# Out:
# Empty DataFrame
# Columns: [gender, genderLooking, age, counts_profileVisits, counts_kisses, counts_fans, country, city, location, lastOnlineDate, lastOnlineTime, userId, Age Category]
# Index: []

# %%
#exporting extra manipulated dataset for future records and possible use
df2.to_csv(os.path.join(r'C:\Users\Samth\CareerFoundry Projects\Achievement 6\1 Data\Manipulated Data\userapi_manipulated_geo_python.csv'))

# %% [markdown]
# # 4 Plotting a Chloropleth

# %%
#creating a dataframe for first map
ageplot= df2[['age','city','location','country']]

# %%
#viewing dataframe
ageplot.head()
# Out:
#    age        city location country
# 0   25  Rothenburg  Rümlang      CH
# 1   22     Sissach  Sissach      CH
# 2   21        Bâle     Bâle      CH
# 3   20    Montréal    Berne      CA
# 4   21     Rastatt  Rastatt      DE

# %%
#creating map with folium
map = folium.Map(location = [0,0], zoom_start = 0)

folium.Choropleth(
    geo_data = geomap, 
    data = ageplot,
    columns = ['age', 'country'],
    key_on = 'feature.properties.name',
    fill_color = 'RdPu', fill_opacity=0.5, line_opacity=0.2,
    legend_name = "age").add_to(map)

folium.LayerControl().add_to(map)

map
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       1 #creating map with folium
#       2 map = folium.Map(location = [0,0], zoom_start = 0)
# ----> 4 folium.Choropleth(
#       5     geo_data = geomap,
#       6     data = ageplot,
#       7     columns = ['age', 'country'],
#       8     key_on = 'feature.properties.name',
#       9     fill_color = 'RdPu', fill_opacity=0.5, line_opacity=0.2,
#      10     legend_name = "age").add_to(map)
#      12 folium.LayerControl().add_to(map)
#      14 map
#
# File ~\anaconda3\Lib\site-packages\folium\features.py:1543, in Choropleth.__init__(self, geo_data, data, columns, key_on, bins, fill_color, nan_fill_color, fill_opacity, nan_fill_opacity, line_color, line_weight, line_opacity, name, legend_name, overlay, control, show, topojson, smooth_factor, highlight, use_jenks, **kwargs)
#    1541 if color_data is not None and key_on is not None:
#    1542     real_values = np.array(list(color_data.values()))
# -> 1543     real_values = real_values[~np.isnan(real_values)]
#    1544     if use_jenks:
#    1545         from jenkspy import jenks_breaks
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
#due to error looking at column types in dataframe to see if there are object values
ageplot.dtypes
# Out:
# age          int64
# city        object
# location    object
# country     object
# dtype: object

# %% [markdown]
# # 5 Commentary

# %% [markdown]
# * As you know my Chloropleth map ended up being made in Tableau as I had issues making it in Python. Below I will be addressing any research questions my map may have answered or questions it may have created!

# %% [markdown]
# ### Although this was not one of the original research questions, our map was able to show us that a majority of our users are located in Germany, France and Italy respectively. This information can be important for marketing and sales as it will allow us to understand which regions may need more marketing to improve our app's visibility. Due to this new information, it also provides further context to one of our research questions "Do women under 25 or over 25 receive more likes?" Since we know a majority of the users are in these three countries, it would be best practice to answer this question by using data only from these countries, as these users have more regular interactions on the app compared to users in a country with less than 100 profiles.
